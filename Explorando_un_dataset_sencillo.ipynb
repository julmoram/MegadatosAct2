# %% [markdown]
# <a href="https://colab.research.google.com/github/julmoram/MegadatosAct2/blob/main/Explorando_un_dataset_sencillo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Actividad 2
# ####Explorando un dataset sencillo
# ####Megadatos

# %% [markdown]
# #####Fatima Juliana Zamora Michel

# %%
#Cargar importaciones
import pandas as pd

# %%
#Abrir el google drive para traer el archivo de datos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
url = '/content/drive/MyDrive/StressLevelDataset.csv'
stress_df = pd.read_csv(url)

# %%
#Contar el número de registros
stress_df.shape[0]
# Out:
# 1100

# %%
#identificar columnas (atributos)
display(stress_df.head())
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
#Detectar un patron o tendencia
stress_df.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %%
#graficar los datos

import matplotlib.pyplot as plt

#distribución de niveles de ansiedad
plt.figure(figsize=(6,4))
stress_df['anxiety_level'].value_counts().sort_index().plot(kind='bar')
plt.title("Distribución de Niveles de Ansiedad")
plt.xlabel("Nivel de Ansiedad")
plt.ylabel("Frecuencia")
plt.show()
